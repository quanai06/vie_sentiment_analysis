# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
train_df_1=pd.read_csv("../data/train_backtranslate.csv")
train_df_2=pd.read_csv("../data/train_resample.csv")
test_df=pd.read_excel("../data/test_nor_811.xlsx")
valid_df=pd.read_excel("../data/valid_nor_811.xlsx")

# %%
train_df_2.tail(10)
# Out:
#       Unnamed: 0    Emotion                                           Sentence
# 6738         422      Anger  địt_mẹ , mình làm_khách_sạn , lúc vào check ph...
# 6739         913    Sadness      tui ở tuy hòa , phú yên mà chả nhận ra luôn .
# 6740         363       Fear           đừng ai lấy cả hộp kẹp của anh ý nhé : (
# 6741         169      Anger  quản_trị viên hỏi thế này thì có khác gì giữa ...
# 6742          37    Disgust  thành_phần_nào cũng có : ) ) ăn_hiếp con_gái :...
# 6743        1035  Enjoyment                    phim hay vãi ấy xem lâu lắm rồi
# 6744         247       Fear                ông thần_tài cũng không dám ăn luôn
# 6745         791    Disgust  cắt . cảm_ơn đoạn giả_dối kia đã giúp các bạn ...
# 6746        1351    Disgust  có rất rất nhìu thanh_niên ở đây bị đứt dây th...
# 6747        1250  Enjoyment  - mấy bạn đừng có đổ mình nữa nha 😞 😞 . mình n...

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.svm import LinearSVC
from sklearn.metrics import classification_report

# %% [markdown]
# DATA BACK_TRANSLATE WITH API GG TRAINSLATE

# %%
full_train=pd.concat([train_df_1,valid_df])

# %%
#TF-IDF vectorizer
vectorriver=TfidfVectorizer()
X_train=vectorriver.fit_transform(full_train["Sentence"])
y_train=full_train["Emotion"]
X_test=vectorriver.transform(test_df["Sentence"])
y_test=test_df["Emotion"]

# %%
model=LinearSVC()
model.fit(X_train,y_train)
# Out:
# LinearSVC()

# %%
y_pred = model.predict(X_test)
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#        Anger       0.19      0.40      0.25        40
#      Disgust       0.47      0.45      0.46       132
#    Enjoyment       0.57      0.55      0.56       193
#         Fear       0.49      0.65      0.56        46
#        Other       0.43      0.34      0.38       129
#      Sadness       0.59      0.41      0.48       116
#     Surprise       0.40      0.51      0.45        37
#
#     accuracy                           0.47       693
#    macro avg       0.45      0.47      0.45       693
# weighted avg       0.49      0.47      0.47       693

# %% [markdown]
# DATA RESAMPLE

# %%
train=pd.concat([train_df_2,valid_df])
vectorriver=TfidfVectorizer()
X_train_2=vectorriver.fit_transform(train["Sentence"])
y_train_2=train["Emotion"]
X_test_2=vectorriver.transform(test_df["Sentence"])
y_test_2=test_df["Emotion"]

# %%
model2=LinearSVC()
model2.fit(X_train_2,y_train_2)
# Out:
# LinearSVC()

# %%
y_pred_2=model2.predict(X_test_2)
print (classification_report(y_test,y_pred_2))
# Out:
#               precision    recall  f1-score   support
#
#        Anger       0.27      0.33      0.29        40
#      Disgust       0.41      0.44      0.42       132
#    Enjoyment       0.54      0.62      0.58       193
#         Fear       0.68      0.57      0.62        46
#        Other       0.40      0.37      0.39       129
#      Sadness       0.53      0.42      0.47       116
#     Surprise       0.61      0.46      0.52        37
#
#     accuracy                           0.48       693
#    macro avg       0.49      0.46      0.47       693
# weighted avg       0.48      0.48      0.48       693
